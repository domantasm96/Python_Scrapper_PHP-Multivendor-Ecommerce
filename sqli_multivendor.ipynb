# %%
#!/usr/bin/python3
from selenium import webdriver
from bs4 import BeautifulSoup
import json
import re
import MySQLdb
import os

DB_NAME = 'Sqli_coursework'
DB_USER = 'test'
DB_PSW = 'test'
HOST = 'localhost'

LOGIN_URL = 'http://www.fxwebsolution.com//demo/arthi/multivendor/sign-in.php'
SELENIUM_PATH = '/home/domantas/Documents/phantomjs-2.1.1-linux-x86_64/bin/phantomjs'
driver = webdriver.PhantomJS(executable_path=SELENIUM_PATH)

ITERATION_NUM = 70

auth_username = 'tesotest22@gmail.com'
auth_password = 'super1234'

os.system("""mysql -utest -p'test' < database_creation""")
db = MySQLdb.connect(host=HOST, user=DB_USER, passwd=DB_PSW, db=DB_NAME)
cursor = db.cursor()
# Out:
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
def login_session():
    driver.get(LOGIN_URL)
    username = driver.find_element_by_id('exampleInputEmail1')
    password = driver.find_element_by_id('exampleInputPassword1')
    username.send_keys(auth_username)
    password.send_keys(auth_password)
    driver.find_element_by_name('loginuser').click()

login_session()

# %%
def remove_spaces(string):
    return re.sub(' {2,}', '_', string)

# %%
def seller_view():
    print('SELLER VIEW SCRIPT IS EXECUTED')
    print('TARGET: http://www.fxwebsolution.com//demo/arthi/multivendor/seller-view.php?usid=')
    data_list = []
    user_list = []
#     ITERATION_NUM
    for uid in range(ITERATION_NUM):
        print('Scraping data from {} user'.format(uid))
        is_empty = True
        driver.get('http://www.fxwebsolution.com//demo/arthi/multivendor/seller-view.php?usid='+str(uid))
        soup = BeautifulSoup(driver.page_source, "lxml")
        info = soup.find_all('div', class_='form-group')
        user_list.append(uid)
        for i in info:
            user_info = i.get_text().strip().replace('\n', ':').split(':')
            if len(user_info) > 1:
                user_list.append(user_info[1])
                is_empty = False
            else:
                user_list.append('')

        data_list.append(user_list)
        user_list = []

    return data_list

seller_data = seller_view()
# Out:
# SELLER VIEW SCRIPT IS EXECUTED
# TARGET: http://www.fxwebsolution.com//demo/arthi/multivendor/seller-view.php?usid=
# Scraping data from 0 user
# Scraping data from 1 user
# Scraping data from 2 user
# Scraping data from 3 user
# Scraping data from 4 user
# Scraping data from 5 user
# Scraping data from 6 user
# Scraping data from 7 user
# Scraping data from 8 user
# Scraping data from 9 user
# Scraping data from 10 user
# Scraping data from 11 user
# Scraping data from 12 user
# Scraping data from 13 user
# Scraping data from 14 user
# Scraping data from 15 user
# Scraping data from 16 user
# Scraping data from 17 user
# Scraping data from 18 user
# Scraping data from 19 user
# Scraping data from 20 user
# Scraping data from 21 user
# Scraping data from 22 user
# Scraping data from 23 user
# Scraping data from 24 user
# Scraping data from 25 user
# Scraping data from 26 user
# Scraping data from 27 user
# Scraping data from 28 user
# Scraping data from 29 user
# Scraping data from 30 user
# Scraping data from 31 user
# Scraping data from 32 user
# Scraping data from 33 user
# Scraping data from 34 user
# Scraping data from 35 user
# Scraping data from 36 user
# Scraping data from 37 user
# Scraping data from 38 user
# Scraping data from 39 user
# Scraping data from 40 user
# Scraping data from 41 user
# Scraping data from 42 user
# Scraping data from 43 user
# Scraping data from 44 user
# Scraping data from 45 user
# Scraping data from 46 user
# Scraping data from 47 user
# Scraping data from 48 user
# Scraping data from 49 user
# Scraping data from 50 user
# Scraping data from 51 user
# Scraping data from 52 user
# Scraping data from 53 user
# Scraping data from 54 user
# Scraping data from 55 user
# Scraping data from 56 user
# Scraping data from 57 user
# Scraping data from 58 user
# Scraping data from 59 user
# Scraping data from 60 user
# Scraping data from 61 user
# Scraping data from 62 user
# Scraping data from 63 user
# Scraping data from 64 user
# Scraping data from 65 user
# Scraping data from 66 user
# Scraping data from 67 user
# Scraping data from 68 user
# Scraping data from 69 user

# %%
def shopping_cart():
    print('SHOPPING CART SCRIPT IS EXECUTED')
    print('TARGET: http://www.fxwebsolution.com/demo/arthi/multivendor/shopping-cart.php?cusid=')
    data_list = []
    temp_list = []
    user_data = []
    cuid_list = []
    for cuid in range(ITERATION_NUM):
        print('Scraping data from {} user'.format(cuid))
        driver.get('http://www.fxwebsolution.com/demo/arthi/multivendor/shopping-cart.php?cusid='+str(cuid))
        soup = BeautifulSoup(driver.page_source, "lxml")
        pattern = soup.find('tbody').find_all('tr')
        if len(pattern) < 1:
            continue
        for product in pattern:
            temp_list.append(cuid)
            for i, elements in enumerate(product.find_all('td')):
                if i == 1:
                    continue
                text = remove_spaces(elements.get_text().replace('\n', ' ').replace('\t', '').replace('\xa0','').strip())
                temp_list.append(text)
            
            data_list.append(temp_list)
            temp_list = []
        cuid_list.append(cuid)
    print('SHOPPING CART SCRIPT IS FINISHED')
    return data_list
cart_data = shopping_cart()
# Out:
# SHOPPING CART SCRIPT IS EXECUTED
# TARGET: http://www.fxwebsolution.com/demo/arthi/multivendor/shopping-cart.php?cusid=
# Scraping data from 0 user
# Scraping data from 1 user
# Scraping data from 2 user
# Scraping data from 3 user
# Scraping data from 4 user
# Scraping data from 5 user
# Scraping data from 6 user
# Scraping data from 7 user
# Scraping data from 8 user
# Scraping data from 9 user
# Scraping data from 10 user
# Scraping data from 11 user
# Scraping data from 12 user
# Scraping data from 13 user
# Scraping data from 14 user
# Scraping data from 15 user
# Scraping data from 16 user
# Scraping data from 17 user
# Scraping data from 18 user
# Scraping data from 19 user
# Scraping data from 20 user
# Scraping data from 21 user
# Scraping data from 22 user
# Scraping data from 23 user
# Scraping data from 24 user
# Scraping data from 25 user
# Scraping data from 26 user
# Scraping data from 27 user
# Scraping data from 28 user
# Scraping data from 29 user
# Scraping data from 30 user
# Scraping data from 31 user
# Scraping data from 32 user
# Scraping data from 33 user
# Scraping data from 34 user
# Scraping data from 35 user
# Scraping data from 36 user
# Scraping data from 37 user
# Scraping data from 38 user
# Scraping data from 39 user
# Scraping data from 40 user
# Scraping data from 41 user
# Scraping data from 42 user
# Scraping data from 43 user
# Scraping data from 44 user
# Scraping data from 45 user
# Scraping data from 46 user
# Scraping data from 47 user
# Scraping data from 48 user
# Scraping data from 49 user
# Scraping data from 50 user
# Scraping data from 51 user
# Scraping data from 52 user
# Scraping data from 53 user
# Scraping data from 54 user
# Scraping data from 55 user
# Scraping data from 56 user
# Scraping data from 57 user
# Scraping data from 58 user
# Scraping data from 59 user
# Scraping data from 60 user
# Scraping data from 61 user
# Scraping data from 62 user
# Scraping data from 63 user
# Scraping data from 64 user
# Scraping data from 65 user
# Scraping data from 66 user
# Scraping data from 67 user
# Scraping data from 68 user
# Scraping data from 69 user
# SHOPPING CART SCRIPT IS FINISHED

# %%
def my_whishlist():
    print('MY WISHLIST SCRIPT IS EXECUTED')
    print('TARGET: http://www.fxwebsolution.com/demo/arthi/multivendor/my_wishlist.php?fid=')
    user_data = []
    for fid in range(ITERATION_NUM):
        print('Scraping data from {} user'.format(fid))
        driver.get('http://www.fxwebsolution.com/demo/arthi/multivendor/my_wishlist.php?fid='+str(fid))
        soup = BeautifulSoup(driver.page_source, "lxml")
        pattern = soup.find_all('tbody')
        if len(pattern[0]) <  1:
            continue
        for product in pattern:
            temp_list = []
            text = remove_spaces(product.get_text().replace('\n', ' ').replace('\t', '').replace('\xa0','').strip())
            if text == '':
                continue
            text = re.sub('(INR[0-9]+){2}',re.search('INR[0-9]+', text)[0], text)
            temp_list.append(fid)
            for i in text.split('_')[:-1]:
                temp_list.append(i)
            user_data.append(temp_list)
    return user_data

wishlist_data = my_whishlist()
# Out:
# MY WISHLIST SCRIPT IS EXECUTED
# TARGET: http://www.fxwebsolution.com/demo/arthi/multivendor/my_wishlist.php?fid=
# Scraping data from 0 user
# Scraping data from 1 user
# Scraping data from 2 user
# Scraping data from 3 user
# Scraping data from 4 user
# Scraping data from 5 user
# Scraping data from 6 user
# Scraping data from 7 user
# Scraping data from 8 user
# Scraping data from 9 user
# Scraping data from 10 user
# Scraping data from 11 user
# Scraping data from 12 user
# Scraping data from 13 user
# Scraping data from 14 user
# Scraping data from 15 user
# Scraping data from 16 user
# Scraping data from 17 user
# Scraping data from 18 user
# Scraping data from 19 user
# Scraping data from 20 user
# Scraping data from 21 user
# Scraping data from 22 user
# Scraping data from 23 user
# Scraping data from 24 user
# Scraping data from 25 user
# Scraping data from 26 user
# Scraping data from 27 user
# Scraping data from 28 user
# Scraping data from 29 user
# Scraping data from 30 user
# Scraping data from 31 user
# Scraping data from 32 user
# Scraping data from 33 user
# Scraping data from 34 user
# Scraping data from 35 user
# Scraping data from 36 user
# Scraping data from 37 user
# Scraping data from 38 user
# Scraping data from 39 user
# Scraping data from 40 user
# Scraping data from 41 user
# Scraping data from 42 user
# Scraping data from 43 user
# Scraping data from 44 user
# Scraping data from 45 user
# Scraping data from 46 user
# Scraping data from 47 user
# Scraping data from 48 user
# Scraping data from 49 user
# Scraping data from 50 user
# Scraping data from 51 user
# Scraping data from 52 user
# Scraping data from 53 user
# Scraping data from 54 user
# Scraping data from 55 user
# Scraping data from 56 user
# Scraping data from 57 user
# Scraping data from 58 user
# Scraping data from 59 user
# Scraping data from 60 user
# Scraping data from 61 user
# Scraping data from 62 user
# Scraping data from 63 user
# Scraping data from 64 user
# Scraping data from 65 user
# Scraping data from 66 user
# Scraping data from 67 user
# Scraping data from 68 user
# Scraping data from 69 user

# %%
def db_seller_insert():
    column_names = '(user_id,name, email,mobile,company,about_company,ph_no,store_name,cancellation_policy,compnay_url,company_address1,company_address2)'
    format_param = ('%s,' * len(seller_data[0:12]))[:-1]
    for i in range(len(seller_data)):
        seller_list = []
        for data in seller_data[i]:
            seller_list.append(data)
        try:
            cursor.execute("INSERT INTO Seller "+ column_names +" VALUES ("+format_param+")""",seller_list[0:12])
            db.commit()
        except:
            db.rollback()
db_seller_insert()

# %%
def db_cart_insert():
    column_names = '(user_id,s_no, product_name,product_rank,product_color,quantity,subtotal,grandtotal)'
    for i in range(len(cart_data)):
        temp = []
        for j in range(len(cart_data[i])-1):
            if(j == 2):
                for values in cart_data[i][j].split('_'):
                    temp.append(values)
            else:
                temp.append(cart_data[i][j])
        format_param = ('%s,' * len(temp))[:-1]
        try:
            cursor.execute("INSERT INTO Cart "+ column_names +" VALUES ("+format_param+")""",temp)
            db.commit()
        except:
            db.rollback()
db_cart_insert();
# Out:
# blue kurti_Not rated yet_COLOR:Blue
# blue kurti_Not rated yet_COLOR:Blue
# lenovo p1m_(5.0)_COLOR:Blue
# Fastrack NG9463AL07 Explorer Analog Watch - For Men_Not rated yet_COLOR:Blue
# Woodland Outdoors_(Green)_(5.0)_COLOR:Green
# lenovo p1m_(5.0)_COLOR:Blue
# sample product 1_Not rated yet_COLOR:Blue
# Sini Mini Girls Printed T Shirt_Not rated yet_COLOR:Multi
# Woodland Outdoors_(Green)_(5.0)_COLOR:Green
# Fastrack NG9463AL07 Explorer Analog Watch - For Men_Not rated yet_COLOR:Blue
# Woodland Outdoors_(Green)_(5.0)_COLOR:Green
# Sini Mini Girls Printed T Shirt_Not rated yet_COLOR:Multi
# T shirts_Not rated yet_COLOR:
# watch_Not rated yet_COLOR:black
# Woodland Outdoors_(Green)_(5.0)_COLOR:Green
# T-shirt_Not rated yet_COLOR:black
# Apple MacBook Air MMGF2HN/A 13.3-inch Laptop (Core i5/8GB/128GB/Mac OS X/Integrated Graphics)_Not rated yet_COLOR:black
# Fastrack NG9463AL07 Explorer Analog Watch - For Men_Not rated yet_COLOR:Blue
# watch_Not rated yet_COLOR:black
# T shirts_Not rated yet_COLOR:
# Anugrah Textile Embroidered Bollywood Georgette, Velvet, Chiffon, Net Saree_(Blue)_(4.0)_COLOR:Blue
# Woodland Outdoors_(Green)_(5.0)_COLOR:Green
# T-shirt_Not rated yet_COLOR:black
# Anugrah Textile Embroidered Bollywood Georgette, Velvet, Chiffon, Net Saree_(Blue)_(4.0)_COLOR:Blue

# %%
def db_wishlist_insert():
    column_names = '(user_id, product_name,product_rank,product_price)'
    format_param = ('%s,' * len(seller_data[0:12]))[:-1]
    for i in range(len(wishlist_data)):
        temp = []
        for j in wishlist_data[i]:
            temp.append(j)
        format_param = ('%s,' * len(temp))[:-1]
        try:
            cursor.execute("INSERT INTO Wishlist "+ column_names +" VALUES ("+format_param+")""",temp)
            db.commit()
        except:
            db.rollback()
db_wishlist_insert();

# %%
driver.close()
db.close()
